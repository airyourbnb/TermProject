# %%
countries = []
amens = []
with open("CountryHT_AverageAmenities.csv",newline='') as f1:
    lines = f1.readlines()
    for x in range (0,len(lines)):
        countries.append([])
        
        entries = lines[x].replace("[","").replace("]","").replace("\"","").replace(" ","").split(",")
        country = entries[0];
        countries[x].append(country)
        for y in range(2, len(entries)):
            countries[x].append(entries[y].lower().replace("\n",""))
            if(not entries[y].lower().replace("\n","") in amens ): 
                amens.append(entries[y].lower().replace("\n",""))

amens = sorted(amens)
for am in amens:
    print(am)
countries
# Out:
# 24-hourcheck-in
# airconditioning
# apartment
# bed&breakfast
# boat
# boutiquehotel
# breakfast
# bungalow
# buzzer/wirelessintercom
# cabin
# cabletv
# camper/rv
# carbonmonoxidedetector
# chalet
# condominium
# doorman
# dorm
# dryer
# elevatorinbuilding
# essentialamenities(>40%oflistings)
# essentials
# family/kidfriendly
# fireextinguisher
# firstaidkit
# freeparkingonpremises
# guesthouse
# guestsuite
# gym
# hairdryer
# hangers
# heating
# hostel
# house
# housingtype
# indoorfireplace
# internet
# iron
# kitchen
# laptopfriendlyworkspace
# lockonbedroomdoor
# loft
# other
# petsallowed
# petsliveonthisproperty
# pool
# safetycard
# servicedapartment
# shampoo
# smokedetector
# timeshare
# townhouse
# translationmissing:en.hosting_amenity_49
# translationmissing:en.hosting_amenity_50
# tv
# villa
# washer
# wirelessinternet
# [['Country', 'housingtype', 'essentialamenities(>40%oflistings)'],
#  ['UnitedStates',
#   'villa',
#   'kitchen',
#   'laptopfriendlyworkspace',
#   'family/kidfriendly',
#   'airconditioning',
#   'iron',
#   'washer',
#   'essentials',
#   'smokedetector',
#   'shampoo',
#   'cabletv',
#   'hangers',
#   'wirelessinternet',
#   'freeparkingonpremises',
#   'tv',
#   'carbonmonoxidedetector',
#   'dryer',
#   'heating',
#   'internet',
#   'hairdryer'],
#  ['UnitedStates',
#   'townhouse',
#   'washer',
#   'airconditioning',
#   'shampoo',
#   'laptopfriendlyworkspace',
#   'hairdryer',
#   'essentials',
#   'smokedetector',
#   'tv',
#   'fireextinguisher',
#   'hangers',
#   'wirelessinternet',
#   'iron',
#   'dryer',
#   'carbonmonoxidedetector',
#   'kitchen',
#   'heating',
#   'internet',
#   'family/kidfriendly',
#   'freeparkingonpremises'],
#  ['UnitedStates',
#   'timeshare',
#   'heating',
#   'carbonmonoxidedetector',
#   'tv',
#   'hangers',
#   'shampoo',
#   'laptopfriendlyworkspace',
#   'wirelessinternet',
#   'internet',
#   'safetycard',
#   'elevatorinbuilding',
#   'fireextinguisher',
#   'essentials',
#   'hairdryer',
#   'washer',
#   'dryer',
#   'iron',
#   'gym',
#   'cabletv',
#   'airconditioning',
#   'kitchen',
#   '24-hourcheck-in',
#   'smokedetector',
#   'family/kidfriendly'],
#  ['UnitedStates',
#   'other',
#   'essentials',
#   'fireextinguisher',
#   'iron',
#   'smokedetector',
#   'airconditioning',
#   'laptopfriendlyworkspace',
#   'carbonmonoxidedetector',
#   'kitchen',
#   'internet',
#   'wirelessinternet',
#   'hairdryer',
#   'hangers',
#   'tv',
#   'shampoo',
#   'heating',
#   'dryer',
#   'washer'],
#  ['UnitedStates',
#   'loft',
#   'washer',
#   'heating',
#   'tv',
#   'fireextinguisher',
#   'laptopfriendlyworkspace',
#   'carbonmonoxidedetector',
#   'essentials',
#   'hairdryer',
#   'smokedetector',
#   'iron',
#   'airconditioning',
#   'shampoo',
#   'internet',
#   'hangers',
#   'dryer',
#   'kitchen',
#   'wirelessinternet'],
#  ['UnitedStates',
#   'house',
#   'internet',
#   'hangers',
#   'tv',
#   'laptopfriendlyworkspace',
#   'essentials',
#   'iron',
#   'kitchen',
#   'washer',
#   'freeparkingonpremises',
#   'fireextinguisher',
#   'shampoo',
#   'wirelessinternet',
#   'family/kidfriendly',
#   'hairdryer',
#   'heating',
#   'dryer',
#   'airconditioning',
#   'smokedetector',
#   'carbonmonoxidedetector'],
#  ['UnitedStates',
#   'hostel',
#   'carbonmonoxidedetector',
#   'washer',
#   'firstaidkit',
#   'heating',
#   'translationmissing:en.hosting_amenity_50',
#   'shampoo',
#   'lockonbedroomdoor',
#   'wirelessinternet',
#   'iron',
#   'hangers',
#   'essentials',
#   'laptopfriendlyworkspace',
#   'airconditioning',
#   'dryer',
#   'smokedetector',
#   'translationmissing:en.hosting_amenity_49',
#   'kitchen',
#   'tv',
#   'fireextinguisher',
#   'hairdryer'],
#  ['UnitedStates',
#   'guesthouse',
#   'freeparkingonpremises',
#   'internet',
#   'shampoo',
#   'tv',
#   'firstaidkit',
#   'carbonmonoxidedetector',
#   'translationmissing:en.hosting_amenity_50',
#   'laptopfriendlyworkspace',
#   'hangers',
#   'kitchen',
#   'wirelessinternet',
#   'lockonbedroomdoor',
#   'heating',
#   'hairdryer',
#   'essentials',
#   'family/kidfriendly',
#   'dryer',
#   'iron',
#   'fireextinguisher',
#   'smokedetector',
#   'washer',
#   'airconditioning'],
#  ['UnitedStates',
#   'guestsuite',
#   'essentials',
#   'airconditioning',
#   'wirelessinternet',
#   'smokedetector',
#   'heating'],
#  ['UnitedStates',
#   'dorm',
#   'translationmissing:en.hosting_amenity_50',
#   'kitchen',
#   'heating',
#   'wirelessinternet',
#   'fireextinguisher',
#   'essentials',
#   'washer',
#   'tv',
#   'iron',
#   'smokedetector',
#   'translationmissing:en.hosting_amenity_49',
#   'internet',
#   'dryer'],
#  ['UnitedStates',
#   'condominium',
#   'heating',
#   'essentials',
#   'kitchen',
#   'tv',
#   'smokedetector',
#   'wirelessinternet',
#   'fireextinguisher',
#   'iron',
#   'family/kidfriendly',
#   'washer',
#   'airconditioning',
#   'dryer',
#   'laptopfriendlyworkspace',
#   'carbonmonoxidedetector',
#   'hairdryer',
#   'shampoo',
#   'internet',
#   'cabletv',
#   'hangers'],
#  ['UnitedStates',
#   'camper/rv',
#   'kitchen',
#   'fireextinguisher',
#   'wirelessinternet',
#   'airconditioning',
#   'hangers',
#   'tv',
#   'freeparkingonpremises',
#   'family/kidfriendly',
#   'shampoo',
#   'heating',
#   'essentials',
#   'smokedetector'],
#  ['UnitedStates',
#   'cabin',
#   'heating',
#   'smokedetector',
#   'hangers',
#   'essentials',
#   'shampoo',
#   'wirelessinternet',
#   'kitchen',
#   'washer',
#   'freeparkingonpremises',
#   'petsliveonthisproperty',
#   'internet',
#   'tv'],
#  ['UnitedStates',
#   'bungalow',
#   'iron',
#   'washer',
#   'dryer',
#   'wirelessinternet',
#   'essentials',
#   'kitchen',
#   'hangers',
#   'family/kidfriendly',
#   'shampoo',
#   'heating',
#   'internet',
#   'laptopfriendlyworkspace',
#   'carbonmonoxidedetector',
#   'freeparkingonpremises',
#   'smokedetector',
#   'fireextinguisher',
#   'airconditioning',
#   'tv',
#   'hairdryer'],
#  ['UnitedStates',
#   'boutiquehotel',
#   'hairdryer',
#   'laptopfriendlyworkspace',
#   'hangers',
#   'family/kidfriendly',
#   'smokedetector',
#   'lockonbedroomdoor',
#   'firstaidkit',
#   'essentials',
#   'iron',
#   'tv',
#   'elevatorinbuilding',
#   'heating',
#   'translationmissing:en.hosting_amenity_50',
#   'fireextinguisher',
#   'airconditioning',
#   'shampoo',
#   'wirelessinternet',
#   'carbonmonoxidedetector'],
#  ['UnitedStates',
#   'boat',
#   'wirelessinternet',
#   'tv',
#   'kitchen',
#   'heating',
#   'essentials'],
#  ['UnitedStates',
#   'bed&breakfast',
#   'smokedetector',
#   'breakfast',
#   'washer',
#   'shampoo',
#   'dryer',
#   'iron',
#   'internet',
#   'airconditioning',
#   'tv',
#   'carbonmonoxidedetector',
#   'heating',
#   'freeparkingonpremises',
#   'essentials',
#   'wirelessinternet',
#   'cabletv',
#   'hairdryer',
#   'hangers',
#   'kitchen',
#   'fireextinguisher',
#   'firstaidkit'],
#  ['UnitedStates',
#   'apartment',
#   'iron',
#   'smokedetector',
#   'wirelessinternet',
#   'internet',
#   'essentials',
#   'hangers',
#   'airconditioning',
#   'family/kidfriendly',
#   'laptopfriendlyworkspace',
#   'washer',
#   'heating',
#   'carbonmonoxidedetector',
#   'tv',
#   'kitchen',
#   'shampoo',
#   'hairdryer',
#   'dryer'],
#  ['UnitedKingdom',
#   'townhouse',
#   'dryer',
#   'shampoo',
#   'kitchen',
#   'family/kidfriendly',
#   'essentials',
#   'smokedetector',
#   'internet',
#   'laptopfriendlyworkspace',
#   'iron',
#   'tv',
#   'washer',
#   'wirelessinternet',
#   'heating',
#   'hairdryer',
#   'carbonmonoxidedetector',
#   'hangers'],
#  ['UnitedKingdom',
#   'other',
#   'hangers',
#   'kitchen',
#   'iron',
#   'smokedetector',
#   'tv',
#   'internet',
#   'heating',
#   'laptopfriendlyworkspace',
#   'wirelessinternet',
#   'shampoo',
#   'essentials',
#   'washer',
#   'translationmissing:en.hosting_amenity_50',
#   'hairdryer'],
#  ['UnitedKingdom',
#   'loft',
#   'essentials',
#   'smokedetector',
#   'translationmissing:en.hosting_amenity_50',
#   'wirelessinternet',
#   'iron',
#   'heating',
#   'hairdryer',
#   'washer',
#   'hangers',
#   'tv',
#   'laptopfriendlyworkspace',
#   'kitchen',
#   'shampoo',
#   'carbonmonoxidedetector',
#   'internet'],
#  ['UnitedKingdom',
#   'house',
#   'smokedetector',
#   'washer',
#   'kitchen',
#   'carbonmonoxidedetector',
#   'family/kidfriendly',
#   'internet',
#   'dryer',
#   'hairdryer',
#   'hangers',
#   'laptopfriendlyworkspace',
#   'iron',
#   'shampoo',
#   'essentials',
#   'tv',
#   'heating',
#   'wirelessinternet'],
#  ['UnitedKingdom',
#   'guesthouse',
#   'essentials',
#   'smokedetector',
#   'wirelessinternet',
#   'heating'],
#  ['UnitedKingdom',
#   'dorm',
#   'translationmissing:en.hosting_amenity_50',
#   'dryer',
#   'internet',
#   'kitchen',
#   'wirelessinternet',
#   'essentials',
#   'heating',
#   'smokedetector',
#   'firstaidkit',
#   'translationmissing:en.hosting_amenity_49',
#   'washer'],
#  ['UnitedKingdom', 'bungalow', 'heating'],
#  ['UnitedKingdom', 'boat', 'kitchen'],
#  ['UnitedKingdom',
#   'bed&breakfast',
#   'shampoo',
#   'carbonmonoxidedetector',
#   'breakfast',
#   'wirelessinternet',
#   'washer',
#   'family/kidfriendly',
#   'iron',
#   'smokedetector',
#   'tv',
#   'hangers',
#   'kitchen',
#   'firstaidkit',
#   'hairdryer',
#   'internet',
#   'essentials',
#   'heating'],
#  ['UnitedKingdom',
#   'apartment',
#   'washer',
#   'internet',
#   'heating',
#   'shampoo',
#   'essentials',
#   'carbonmonoxidedetector',
#   'hairdryer',
#   'smokedetector',
#   'family/kidfriendly',
#   'wirelessinternet',
#   'tv',
#   'iron',
#   'laptopfriendlyworkspace',
#   'hangers',
#   'kitchen',
#   'dryer'],
#  ['Switzerland',
#   'house',
#   'hangers',
#   'washer',
#   'shampoo',
#   'freeparkingonpremises',
#   'wirelessinternet',
#   'dryer',
#   'iron',
#   'essentials',
#   'family/kidfriendly',
#   'heating',
#   'kitchen',
#   'internet',
#   'tv'],
#  ['Switzerland',
#   'apartment',
#   'washer',
#   'hairdryer',
#   'wirelessinternet',
#   'shampoo',
#   'laptopfriendlyworkspace',
#   'iron',
#   'tv',
#   'kitchen',
#   'internet',
#   'elevatorinbuilding',
#   'family/kidfriendly',
#   'heating',
#   'essentials',
#   'hangers'],
#  ['Spain',
#   'villa',
#   'wirelessinternet',
#   'family/kidfriendly',
#   'washer',
#   'kitchen',
#   'airconditioning',
#   'internet',
#   'tv',
#   'hangers',
#   'iron',
#   'cabletv',
#   'hairdryer',
#   'freeparkingonpremises',
#   'heating',
#   'essentials',
#   'pool',
#   'indoorfireplace'],
#  ['Spain',
#   'townhouse',
#   'tv',
#   'family/kidfriendly',
#   'hangers',
#   'internet',
#   'hairdryer',
#   'heating',
#   'pool',
#   'laptopfriendlyworkspace',
#   'airconditioning',
#   'kitchen',
#   'iron',
#   'wirelessinternet',
#   'washer',
#   'freeparkingonpremises',
#   'essentials'],
#  ['Spain',
#   'other',
#   'airconditioning',
#   'shampoo',
#   'family/kidfriendly',
#   'washer',
#   'translationmissing:en.hosting_amenity_50',
#   'tv',
#   'wirelessinternet',
#   'hangers',
#   'elevatorinbuilding',
#   'hairdryer',
#   'kitchen',
#   'essentials',
#   'laptopfriendlyworkspace',
#   'heating',
#   'iron'],
#  ['Spain',
#   'loft',
#   'wirelessinternet',
#   'washer',
#   'kitchen',
#   'heating',
#   'airconditioning',
#   'family/kidfriendly',
#   'iron',
#   'hairdryer',
#   'internet',
#   'elevatorinbuilding',
#   'hangers',
#   'tv',
#   'laptopfriendlyworkspace',
#   'shampoo',
#   'essentials'],
#  ['Spain',
#   'house',
#   'washer',
#   'essentials',
#   'wirelessinternet',
#   'indoorfireplace',
#   'iron',
#   'cabletv',
#   'heating',
#   'tv',
#   'internet',
#   'family/kidfriendly',
#   'hairdryer',
#   'airconditioning',
#   'hangers',
#   'pool',
#   'kitchen',
#   'freeparkingonpremises'],
#  ['Spain',
#   'guesthouse',
#   'wirelessinternet',
#   'heating',
#   'family/kidfriendly',
#   'essentials',
#   'kitchen',
#   'hangers',
#   'hairdryer'],
#  ['Spain', 'dorm', 'heating', 'wirelessinternet', 'kitchen'],
#  ['Spain',
#   'condominium',
#   'hairdryer',
#   'buzzer/wirelessintercom',
#   'heating',
#   'internet',
#   'family/kidfriendly',
#   'iron',
#   'washer',
#   'tv',
#   'essentials',
#   'wirelessinternet',
#   'kitchen',
#   'elevatorinbuilding',
#   'hangers',
#   'laptopfriendlyworkspace',
#   'shampoo',
#   'airconditioning'],
#  ['Spain',
#   'chalet',
#   'internet',
#   'freeparkingonpremises',
#   'kitchen',
#   'wirelessinternet',
#   'cabletv',
#   'heating',
#   'pool',
#   'hangers',
#   'family/kidfriendly',
#   'airconditioning',
#   'tv',
#   'iron',
#   'hairdryer',
#   'indoorfireplace',
#   'essentials',
#   'washer'],
#  ['Spain',
#   'bed&breakfast',
#   'hangers',
#   'elevatorinbuilding',
#   'tv',
#   'essentials',
#   'wirelessinternet',
#   'kitchen',
#   'airconditioning',
#   'laptopfriendlyworkspace',
#   'heating',
#   'family/kidfriendly',
#   'breakfast',
#   'hairdryer',
#   'shampoo',
#   'washer',
#   'firstaidkit',
#   'internet',
#   'iron'],
#  ['Spain',
#   'apartment',
#   'shampoo',
#   'essentials',
#   'iron',
#   'hangers',
#   'kitchen',
#   'buzzer/wirelessintercom',
#   'laptopfriendlyworkspace',
#   'internet',
#   'elevatorinbuilding',
#   'tv',
#   'hairdryer',
#   'heating',
#   'wirelessinternet',
#   'washer',
#   'family/kidfriendly',
#   'airconditioning'],
#  ['Netherlands',
#   'townhouse',
#   'family/kidfriendly',
#   'cabletv',
#   'fireextinguisher',
#   'smokedetector',
#   'shampoo',
#   'wirelessinternet',
#   'kitchen',
#   'essentials',
#   'firstaidkit',
#   'internet',
#   'tv',
#   'heating',
#   'laptopfriendlyworkspace',
#   'hairdryer',
#   'hangers',
#   'washer',
#   'dryer',
#   'iron'],
#  ['Netherlands', 'other', 'heating', 'essentials', 'wirelessinternet'],
#  ['Netherlands',
#   'loft',
#   'fireextinguisher',
#   'essentials',
#   'family/kidfriendly',
#   'iron',
#   'wirelessinternet',
#   'heating',
#   'laptopfriendlyworkspace',
#   'smokedetector',
#   'kitchen',
#   'cabletv',
#   'shampoo',
#   'hairdryer',
#   'internet',
#   'washer',
#   'hangers',
#   'tv'],
#  ['Netherlands',
#   'house',
#   'hangers',
#   'washer',
#   'shampoo',
#   'tv',
#   'fireextinguisher',
#   'hairdryer',
#   'dryer',
#   'iron',
#   'essentials',
#   'internet',
#   'firstaidkit',
#   'smokedetector',
#   'wirelessinternet',
#   'cabletv',
#   'kitchen',
#   'heating',
#   'family/kidfriendly',
#   'laptopfriendlyworkspace'],
#  ['Netherlands',
#   'condominium',
#   'firstaidkit',
#   'kitchen',
#   'essentials',
#   'wirelessinternet',
#   'internet',
#   'hairdryer',
#   'hangers',
#   'family/kidfriendly',
#   'laptopfriendlyworkspace',
#   'washer',
#   'heating',
#   'shampoo',
#   'smokedetector',
#   'iron',
#   'cabletv',
#   'tv'],
#  ['Netherlands',
#   'boat',
#   'hangers',
#   'tv',
#   'essentials',
#   'family/kidfriendly',
#   'laptopfriendlyworkspace',
#   'fireextinguisher',
#   'heating',
#   'kitchen',
#   'wirelessinternet',
#   'washer',
#   'shampoo',
#   'internet',
#   'hairdryer',
#   'smokedetector',
#   'dryer',
#   'cabletv',
#   'firstaidkit'],
#  ['Netherlands',
#   'bed&breakfast',
#   'tv',
#   'smokedetector',
#   'family/kidfriendly',
#   'hangers',
#   'laptopfriendlyworkspace',
#   'fireextinguisher',
#   'internet',
#   'breakfast',
#   'kitchen',
#   'shampoo',
#   'firstaidkit',
#   'heating',
#   'wirelessinternet',
#   'washer',
#   'hairdryer',
#   'carbonmonoxidedetector',
#   'cabletv',
#   'iron',
#   'essentials'],
#  ['Netherlands',
#   'apartment',
#   'cabletv',
#   'family/kidfriendly',
#   'wirelessinternet',
#   'heating',
#   'smokedetector',
#   'kitchen',
#   'hangers',
#   'laptopfriendlyworkspace',
#   'shampoo',
#   'hairdryer',
#   'washer',
#   'internet',
#   'iron',
#   'essentials',
#   'dryer',
#   'tv'],
#  ['Italy',
#   'villa',
#   'heating',
#   'kitchen',
#   'shampoo',
#   'petsallowed',
#   'internet',
#   'hairdryer',
#   'airconditioning',
#   'washer',
#   'hangers',
#   'wirelessinternet',
#   'family/kidfriendly',
#   'firstaidkit',
#   'tv',
#   'laptopfriendlyworkspace',
#   'iron',
#   'freeparkingonpremises',
#   'essentials'],
#  ['Italy',
#   'servicedapartment',
#   'lockonbedroomdoor',
#   'family/kidfriendly',
#   'elevatorinbuilding',
#   'fireextinguisher',
#   'heating',
#   'firstaidkit',
#   'shampoo',
#   'essentials',
#   'airconditioning',
#   'hairdryer',
#   'hangers',
#   'laptopfriendlyworkspace',
#   'wirelessinternet',
#   'tv'],
#  ['Italy',
#   'other',
#   'hangers',
#   'laptopfriendlyworkspace',
#   'shampoo',
#   'firstaidkit',
#   'fireextinguisher',
#   'wirelessinternet',
#   'tv',
#   'family/kidfriendly',
#   'essentials',
#   'elevatorinbuilding',
#   'airconditioning',
#   'heating',
#   'hairdryer'],
#  ['Italy',
#   'loft',
#   'hangers',
#   'wirelessinternet',
#   'heating',
#   'essentials',
#   'tv',
#   'hairdryer',
#   'iron',
#   'firstaidkit',
#   'internet',
#   'airconditioning',
#   'laptopfriendlyworkspace',
#   'kitchen',
#   'washer',
#   'family/kidfriendly',
#   'shampoo'],
#  ['Italy',
#   'house',
#   'shampoo',
#   'essentials',
#   'tv',
#   'laptopfriendlyworkspace',
#   'heating',
#   'wirelessinternet',
#   'internet',
#   'hairdryer',
#   'kitchen',
#   'hangers',
#   'washer',
#   'iron',
#   'family/kidfriendly',
#   'airconditioning'],
#  ['Italy',
#   'condominium',
#   'laptopfriendlyworkspace',
#   'hairdryer',
#   'airconditioning',
#   'internet',
#   'shampoo',
#   'kitchen',
#   'heating',
#   'wirelessinternet',
#   'elevatorinbuilding',
#   'family/kidfriendly',
#   'iron',
#   'firstaidkit',
#   'essentials',
#   'tv',
#   'hangers',
#   'washer'],
#  ['Italy',
#   'boutiquehotel',
#   'airconditioning',
#   'wirelessinternet',
#   'tv',
#   'essentials',
#   'heating',
#   'shampoo'],
#  ['Italy',
#   'bed&breakfast',
#   'internet',
#   'heating',
#   'family/kidfriendly',
#   'hangers',
#   'hairdryer',
#   'wirelessinternet',
#   'essentials',
#   'fireextinguisher',
#   'elevatorinbuilding',
#   'airconditioning',
#   'firstaidkit',
#   'tv',
#   'shampoo',
#   'breakfast'],
#  ['Italy',
#   'apartment',
#   'hairdryer',
#   'heating',
#   'hangers',
#   'essentials',
#   'iron',
#   'internet',
#   'elevatorinbuilding',
#   'kitchen',
#   'wirelessinternet',
#   'family/kidfriendly',
#   'washer',
#   'shampoo',
#   'laptopfriendlyworkspace',
#   'tv',
#   'airconditioning'],
#  ['Ireland',
#   'townhouse',
#   'smokedetector',
#   'hangers',
#   'shampoo',
#   'hairdryer',
#   'washer',
#   'wirelessinternet',
#   'tv',
#   'essentials',
#   'heating',
#   'kitchen',
#   'iron'],
#  ['Ireland',
#   'house',
#   'dryer',
#   'hangers',
#   'washer',
#   'iron',
#   'internet',
#   'tv',
#   'heating',
#   'wirelessinternet',
#   'shampoo',
#   'fireextinguisher',
#   'kitchen',
#   'indoorfireplace',
#   'carbonmonoxidedetector',
#   'family/kidfriendly',
#   'firstaidkit',
#   'hairdryer',
#   'freeparkingonpremises',
#   'essentials',
#   'laptopfriendlyworkspace',
#   'smokedetector'],
#  ['Ireland',
#   'bed&breakfast',
#   'fireextinguisher',
#   'essentials',
#   'breakfast',
#   'indoorfireplace',
#   'family/kidfriendly',
#   'internet',
#   'iron',
#   'carbonmonoxidedetector',
#   'firstaidkit',
#   'heating',
#   'hairdryer',
#   'kitchen',
#   'washer',
#   'smokedetector',
#   'wirelessinternet',
#   'freeparkingonpremises',
#   'hangers',
#   'shampoo',
#   'tv'],
#  ['Ireland',
#   'apartment',
#   'shampoo',
#   'washer',
#   'dryer',
#   'heating',
#   'iron',
#   'essentials',
#   'laptopfriendlyworkspace',
#   'wirelessinternet',
#   'hairdryer',
#   'fireextinguisher',
#   'elevatorinbuilding',
#   'tv',
#   'internet',
#   'family/kidfriendly',
#   'smokedetector',
#   'kitchen',
#   'hangers'],
#  ['HongKong',
#   'house',
#   'hangers',
#   'family/kidfriendly',
#   'airconditioning',
#   'fireextinguisher',
#   'internet',
#   'tv',
#   'elevatorinbuilding',
#   'hairdryer',
#   'smokedetector',
#   'shampoo',
#   'wirelessinternet',
#   'washer',
#   'kitchen',
#   'essentials'],
#  ['HongKong',
#   'dorm',
#   'airconditioning',
#   'doorman',
#   'tv',
#   'washer',
#   'shampoo',
#   'elevatorinbuilding',
#   'firstaidkit',
#   'fireextinguisher',
#   'internet',
#   'essentials',
#   'family/kidfriendly',
#   'hairdryer',
#   'wirelessinternet',
#   'hangers',
#   'smokedetector',
#   'carbonmonoxidedetector'],
#  ['HongKong',
#   'apartment',
#   'tv',
#   'hairdryer',
#   'shampoo',
#   'elevatorinbuilding',
#   'family/kidfriendly',
#   'essentials',
#   'airconditioning',
#   'hangers',
#   'internet',
#   'washer',
#   'wirelessinternet',
#   'kitchen'],
#  ['Greece',
#   'house',
#   'laptopfriendlyworkspace',
#   'shampoo',
#   'wirelessinternet',
#   'hangers',
#   'essentials',
#   'firstaidkit',
#   'fireextinguisher',
#   'family/kidfriendly',
#   'iron',
#   'washer',
#   'kitchen',
#   'heating',
#   'tv',
#   'airconditioning',
#   'internet',
#   'hairdryer'],
#  ['Greece',
#   'apartment',
#   'tv',
#   'heating',
#   'laptopfriendlyworkspace',
#   'elevatorinbuilding',
#   'kitchen',
#   'firstaidkit',
#   'hangers',
#   'shampoo',
#   'airconditioning',
#   'hairdryer',
#   'iron',
#   'family/kidfriendly',
#   'essentials',
#   'internet',
#   'wirelessinternet',
#   'washer'],
#  ['Germany', 'other', 'kitchen', 'heating', 'wirelessinternet'],
#  ['Germany',
#   'loft',
#   'hangers',
#   'shampoo',
#   'essentials',
#   'family/kidfriendly',
#   'iron',
#   'internet',
#   'wirelessinternet',
#   'washer',
#   'heating',
#   'tv',
#   'laptopfriendlyworkspace',
#   'buzzer/wirelessintercom',
#   'kitchen',
#   'hairdryer',
#   'smokedetector'],
#  ['Germany',
#   'house',
#   'freeparkingonpremises',
#   'family/kidfriendly',
#   'smokedetector',
#   'essentials',
#   'laptopfriendlyworkspace',
#   'hangers',
#   'washer',
#   'wirelessinternet',
#   'kitchen',
#   'heating',
#   'tv',
#   'internet',
#   'hairdryer',
#   'iron'],
#  ['Germany',
#   'condominium',
#   'essentials',
#   'family/kidfriendly',
#   'hangers',
#   'kitchen',
#   'washer',
#   'hairdryer',
#   'wirelessinternet',
#   'laptopfriendlyworkspace',
#   'tv',
#   'heating',
#   'shampoo',
#   'internet',
#   'buzzer/wirelessintercom',
#   'iron'],
#  ['Germany',
#   'bed&breakfast',
#   'iron',
#   'laptopfriendlyworkspace',
#   'internet',
#   'wirelessinternet',
#   'hairdryer',
#   'hangers',
#   'washer',
#   'shampoo',
#   'heating',
#   'essentials',
#   'family/kidfriendly',
#   'tv',
#   'breakfast',
#   'kitchen'],
#  ['Germany',
#   'apartment',
#   'essentials',
#   'internet',
#   'heating',
#   'iron',
#   'hangers',
#   'shampoo',
#   'buzzer/wirelessintercom',
#   'tv',
#   'kitchen',
#   'wirelessinternet',
#   'laptopfriendlyworkspace',
#   'hairdryer',
#   'family/kidfriendly',
#   'washer'],
#  ['France',
#   'townhouse',
#   'essentials',
#   'heating',
#   'kitchen',
#   'wirelessinternet'],
#  ['France',
#   'other',
#   'elevatorinbuilding',
#   'shampoo',
#   'family/kidfriendly',
#   'wirelessinternet',
#   'internet',
#   'essentials',
#   'laptopfriendlyworkspace',
#   'heating',
#   '24-hourcheck-in',
#   'hangers',
#   'hairdryer',
#   'smokedetector',
#   'iron',
#   'kitchen',
#   'tv'],
#  ['France',
#   'loft',
#   'hangers',
#   'dryer',
#   'laptopfriendlyworkspace',
#   'heating',
#   'cabletv',
#   'smokedetector',
#   'hairdryer',
#   'kitchen',
#   'essentials',
#   'tv',
#   'wirelessinternet',
#   'washer',
#   'shampoo',
#   'iron',
#   'internet',
#   'family/kidfriendly'],
#  ['France',
#   'house',
#   'dryer',
#   'hairdryer',
#   'laptopfriendlyworkspace',
#   'washer',
#   'kitchen',
#   'tv',
#   'shampoo',
#   'hangers',
#   'wirelessinternet',
#   'heating',
#   'iron',
#   'smokedetector',
#   'family/kidfriendly',
#   'internet',
#   'essentials'],
#  ['France', 'guesthouse', 'heating', 'wirelessinternet'],
#  ['France',
#   'condominium',
#   'laptopfriendlyworkspace',
#   'heating',
#   'washer',
#   'smokedetector',
#   'hangers',
#   'shampoo',
#   'internet',
#   'family/kidfriendly',
#   'elevatorinbuilding',
#   'kitchen',
#   'iron',
#   'hairdryer',
#   'wirelessinternet',
#   'tv',
#   'essentials'],
#  ['France',
#   'boutiquehotel',
#   'laptopfriendlyworkspace',
#   'family/kidfriendly',
#   'iron',
#   'safetycard',
#   'breakfast',
#   'elevatorinbuilding',
#   'tv',
#   'essentials',
#   'airconditioning',
#   'smokedetector',
#   'hangers',
#   'fireextinguisher',
#   'heating',
#   'wirelessinternet',
#   'hairdryer',
#   'shampoo',
#   'lockonbedroomdoor'],
#  ['France',
#   'bed&breakfast',
#   'essentials',
#   'kitchen',
#   'heating',
#   'tv',
#   'washer',
#   'elevatorinbuilding',
#   'breakfast',
#   'internet',
#   'hairdryer',
#   'smokedetector',
#   'iron',
#   'family/kidfriendly',
#   'laptopfriendlyworkspace',
#   'shampoo',
#   'wirelessinternet',
#   'hangers'],
#  ['France',
#   'apartment',
#   'laptopfriendlyworkspace',
#   'tv',
#   'heating',
#   'hangers',
#   'internet',
#   'hairdryer',
#   'smokedetector',
#   'family/kidfriendly',
#   'kitchen',
#   'iron',
#   'shampoo',
#   'elevatorinbuilding',
#   'essentials',
#   'wirelessinternet',
#   'washer'],
#  ['Denmark', 'villa', 'wirelessinternet', 'freeparkingonpremises', 'heating'],
#  ['Denmark',
#   'townhouse',
#   'kitchen',
#   'heating',
#   'essentials',
#   'wirelessinternet'],
#  ['Denmark',
#   'house',
#   'tv',
#   'iron',
#   'wirelessinternet',
#   'essentials',
#   'washer',
#   'kitchen',
#   'heating',
#   'laptopfriendlyworkspace',
#   'internet',
#   'smokedetector',
#   'dryer',
#   'family/kidfriendly',
#   'hairdryer',
#   'hangers',
#   'freeparkingonpremises'],
#  ['Denmark', 'bed&breakfast', 'heating', 'essentials', 'wirelessinternet'],
#  ['Denmark',
#   'apartment',
#   'washer',
#   'family/kidfriendly',
#   'laptopfriendlyworkspace',
#   'essentials',
#   'iron',
#   'heating',
#   'wirelessinternet',
#   'internet',
#   'buzzer/wirelessintercom',
#   'hangers',
#   'smokedetector',
#   'tv',
#   'shampoo',
#   'hairdryer',
#   'kitchen'],
#  ['Canada',
#   'townhouse',
#   'washer',
#   'carbonmonoxidedetector',
#   'tv',
#   'internet',
#   'wirelessinternet',
#   'smokedetector',
#   'laptopfriendlyworkspace',
#   'shampoo',
#   'heating',
#   'hangers',
#   'essentials',
#   'dryer',
#   'iron',
#   'airconditioning',
#   'kitchen',
#   'freeparkingonpremises',
#   'hairdryer',
#   'family/kidfriendly'],
#  ['Canada',
#   'other',
#   'hangers',
#   'laptopfriendlyworkspace',
#   'carbonmonoxidedetector',
#   'internet',
#   'family/kidfriendly',
#   'freeparkingonpremises',
#   'essentials',
#   'tv',
#   'heating',
#   'fireextinguisher',
#   'shampoo',
#   'smokedetector',
#   'washer',
#   'dryer',
#   'wirelessinternet',
#   'iron',
#   'kitchen',
#   'hairdryer'],
#  ['Canada',
#   'loft',
#   'kitchen',
#   'essentials',
#   'smokedetector',
#   'dryer',
#   'shampoo',
#   'tv',
#   'iron',
#   'hangers',
#   'washer',
#   'heating',
#   'wirelessinternet',
#   'internet'],
#  ['Canada',
#   'house',
#   'fireextinguisher',
#   'essentials',
#   'family/kidfriendly',
#   'kitchen',
#   'hangers',
#   'wirelessinternet',
#   'carbonmonoxidedetector',
#   'dryer',
#   'smokedetector',
#   'freeparkingonpremises',
#   'iron',
#   'tv',
#   'hairdryer',
#   'heating',
#   'shampoo',
#   'laptopfriendlyworkspace',
#   'internet',
#   'washer',
#   'airconditioning'],
#  ['Canada',
#   'guesthouse',
#   'fireextinguisher',
#   'family/kidfriendly',
#   'wirelessinternet',
#   'kitchen',
#   'shampoo',
#   'smokedetector',
#   'laptopfriendlyworkspace',
#   'airconditioning',
#   'essentials',
#   'heating',
#   'dryer',
#   'washer',
#   'hairdryer',
#   'iron',
#   'hangers',
#   'carbonmonoxidedetector'],
#  ['Canada',
#   'condominium',
#   'laptopfriendlyworkspace',
#   'elevatorinbuilding',
#   'hangers',
#   'freeparkingonpremises',
#   'tv',
#   'iron',
#   'wirelessinternet',
#   'pool',
#   'essentials',
#   'dryer',
#   'shampoo',
#   'gym',
#   'kitchen',
#   'washer',
#   'internet',
#   'heating',
#   'smokedetector',
#   'family/kidfriendly',
#   'airconditioning',
#   'hairdryer',
#   'carbonmonoxidedetector'],
#  ['Canada',
#   'bungalow',
#   'hangers',
#   'kitchen',
#   'tv',
#   'essentials',
#   'airconditioning',
#   'laptopfriendlyworkspace',
#   'hairdryer',
#   'washer',
#   'dryer',
#   'heating',
#   'shampoo',
#   'freeparkingonpremises',
#   'wirelessinternet',
#   'carbonmonoxidedetector',
#   'smokedetector'],
#  ['Canada',
#   'bed&breakfast',
#   'hangers',
#   'washer',
#   'breakfast',
#   'dryer',
#   'shampoo',
#   'kitchen',
#   'wirelessinternet',
#   'tv',
#   'smokedetector',
#   'internet',
#   'heating',
#   'essentials'],
#  ['Canada',
#   'apartment',
#   'wirelessinternet',
#   'essentials',
#   'internet',
#   'smokedetector',
#   'tv',
#   'washer',
#   'heating',
#   'hangers',
#   'kitchen',
#   'iron',
#   'shampoo',
#   'dryer'],
#  ['Belgium',
#   'townhouse',
#   'smokedetector',
#   'kitchen',
#   'hangers',
#   'hairdryer',
#   'washer',
#   'iron',
#   'essentials',
#   'tv',
#   'family/kidfriendly',
#   'shampoo',
#   'laptopfriendlyworkspace',
#   'heating',
#   'wirelessinternet'],
#  ['Belgium',
#   'loft',
#   'wirelessinternet',
#   'internet',
#   'tv',
#   'hairdryer',
#   'shampoo',
#   'hangers',
#   'iron',
#   'kitchen',
#   'washer',
#   'buzzer/wirelessintercom',
#   'fireextinguisher',
#   'heating',
#   'smokedetector',
#   'essentials',
#   'family/kidfriendly',
#   'laptopfriendlyworkspace'],
#  ['Belgium',
#   'house',
#   'wirelessinternet',
#   'shampoo',
#   'iron',
#   'laptopfriendlyworkspace',
#   'smokedetector',
#   'internet',
#   'kitchen',
#   'hangers',
#   'family/kidfriendly',
#   'essentials',
#   'tv',
#   'hairdryer',
#   'washer',
#   'heating'],
#  ['Belgium',
#   'condominium',
#   'essentials',
#   'kitchen',
#   'heating',
#   'wirelessinternet',
#   'smokedetector'],
#  ['Belgium',
#   'bed&breakfast',
#   'fireextinguisher',
#   'family/kidfriendly',
#   'cabletv',
#   'essentials',
#   'hairdryer',
#   'heating',
#   'smokedetector',
#   'wirelessinternet',
#   'hangers',
#   'internet',
#   'shampoo',
#   'kitchen',
#   'laptopfriendlyworkspace',
#   'tv',
#   'breakfast'],
#  ['Belgium',
#   'apartment',
#   'kitchen',
#   'washer',
#   'tv',
#   'smokedetector',
#   'heating',
#   'laptopfriendlyworkspace',
#   'buzzer/wirelessintercom',
#   'family/kidfriendly',
#   'hangers',
#   'hairdryer',
#   'wirelessinternet',
#   'essentials',
#   'shampoo',
#   'iron',
#   'internet'],
#  ['Austria',
#   'house',
#   'family/kidfriendly',
#   'hairdryer',
#   'freeparkingonpremises',
#   'hangers',
#   'internet',
#   'laptopfriendlyworkspace',
#   'kitchen',
#   'essentials',
#   'washer',
#   'heating',
#   'wirelessinternet',
#   'tv',
#   'iron'],
#  ['Austria',
#   'condominium',
#   'washer',
#   'tv',
#   'heating',
#   'elevatorinbuilding',
#   'shampoo',
#   'laptopfriendlyworkspace',
#   'internet',
#   'hairdryer',
#   'family/kidfriendly',
#   'wirelessinternet',
#   'essentials',
#   'hangers',
#   'iron',
#   'buzzer/wirelessintercom',
#   'kitchen'],
#  ['Austria',
#   'apartment',
#   'family/kidfriendly',
#   'hairdryer',
#   'buzzer/wirelessintercom',
#   'wirelessinternet',
#   'laptopfriendlyworkspace',
#   'internet',
#   'washer',
#   'elevatorinbuilding',
#   'hangers',
#   'heating',
#   'iron',
#   'tv',
#   'shampoo',
#   'essentials',
#   'kitchen'],
#  ['Australia',
#   'villa',
#   'washer',
#   'hairdryer',
#   'smokedetector',
#   'iron',
#   'internet',
#   'kitchen',
#   'essentials',
#   'laptopfriendlyworkspace',
#   'airconditioning',
#   'heating',
#   'shampoo',
#   'tv',
#   'hangers',
#   'family/kidfriendly',
#   'wirelessinternet',
#   'freeparkingonpremises',
#   'dryer'],
#  ['Australia',
#   'townhouse',
#   'wirelessinternet',
#   'laptopfriendlyworkspace',
#   'hairdryer',
#   'internet',
#   'hangers',
#   'essentials',
#   'shampoo',
#   'freeparkingonpremises',
#   'kitchen',
#   'heating',
#   'dryer',
#   'family/kidfriendly',
#   'iron',
#   'smokedetector',
#   'tv',
#   'washer',
#   'airconditioning'],
#  ['Australia',
#   'other',
#   'fireextinguisher',
#   'kitchen',
#   'firstaidkit',
#   'iron',
#   'washer',
#   'heating',
#   'tv',
#   'shampoo',
#   'internet',
#   'essentials',
#   'smokedetector',
#   'family/kidfriendly',
#   'hangers',
#   'wirelessinternet',
#   'dryer'],
#  ['Australia',
#   'loft',
#   'tv',
#   'hangers',
#   'kitchen',
#   'heating',
#   'internet',
#   'essentials',
#   'smokedetector',
#   'washer',
#   'wirelessinternet',
#   'airconditioning',
#   'shampoo',
#   'iron'],
#  ['Australia',
#   'house',
#   'dryer',
#   'family/kidfriendly',
#   'internet',
#   'smokedetector',
#   'tv',
#   'airconditioning',
#   'hangers',
#   'wirelessinternet',
#   'freeparkingonpremises',
#   'laptopfriendlyworkspace',
#   'heating',
#   'hairdryer',
#   'washer',
#   'iron',
#   'shampoo',
#   'kitchen',
#   'essentials'],
#  ['Australia',
#   'guesthouse',
#   'family/kidfriendly',
#   'smokedetector',
#   'washer',
#   'hairdryer',
#   'tv',
#   'wirelessinternet',
#   'kitchen',
#   'hangers',
#   'lockonbedroomdoor',
#   'shampoo',
#   'heating',
#   'essentials',
#   'laptopfriendlyworkspace',
#   'iron'],
#  ['Australia', 'dorm', 'wirelessinternet', 'kitchen', 'washer'],
#  ['Australia',
#   'cabin',
#   'iron',
#   'smokedetector',
#   'tv',
#   'essentials',
#   'hangers',
#   'shampoo',
#   'kitchen',
#   'petsliveonthisproperty',
#   'wirelessinternet',
#   'washer',
#   'heating'],
#  ['Australia',
#   'bungalow',
#   'essentials',
#   'wirelessinternet',
#   'internet',
#   'family/kidfriendly',
#   'laptopfriendlyworkspace',
#   'tv',
#   'iron',
#   'heating',
#   'hangers',
#   'shampoo',
#   'smokedetector',
#   'freeparkingonpremises',
#   'hairdryer',
#   'kitchen',
#   'washer'],
#  ['Australia',
#   'bed&breakfast',
#   'breakfast',
#   'laptopfriendlyworkspace',
#   'firstaidkit',
#   'kitchen',
#   'airconditioning',
#   'heating',
#   'hairdryer',
#   'essentials',
#   'freeparkingonpremises',
#   'iron',
#   'shampoo',
#   'dryer',
#   'wirelessinternet',
#   'internet',
#   'tv',
#   'washer',
#   'family/kidfriendly',
#   'hangers',
#   'smokedetector'],
#  ['Australia',
#   'apartment',
#   'wirelessinternet',
#   'tv',
#   'internet',
#   'hangers',
#   'heating',
#   'smokedetector',
#   'essentials',
#   'laptopfriendlyworkspace',
#   'airconditioning',
#   'iron',
#   'shampoo',
#   'dryer',
#   'family/kidfriendly',
#   'freeparkingonpremises',
#   'elevatorinbuilding',
#   'hairdryer',
#   'washer',
#   'kitchen']]

# %%
results = []

header = "Country"
for am in amens:
    header += "," + am.replace("\n","")


results.append(header)
    
for country in countries:
    res = country[0]
    for am in amens:
        if am in country:
            res += ",yes"
        else: res += ",no"
    results.append(res)

# %%
results
# Out:
# ['Country,24-hourcheck-in,airconditioning,apartment,bed&breakfast,boat,boutiquehotel,breakfast,bungalow,buzzer/wirelessintercom,cabin,cabletv,camper/rv,carbonmonoxidedetector,chalet,condominium,doorman,dorm,dryer,elevatorinbuilding,essentialamenities(>40%oflistings),essentials,family/kidfriendly,fireextinguisher,firstaidkit,freeparkingonpremises,guesthouse,guestsuite,gym,hairdryer,hangers,heating,hostel,house,housingtype,indoorfireplace,internet,iron,kitchen,laptopfriendlyworkspace,lockonbedroomdoor,loft,other,petsallowed,petsliveonthisproperty,pool,safetycard,servicedapartment,shampoo,smokedetector,timeshare,townhouse,translationmissing:en.hosting_amenity_49,translationmissing:en.hosting_amenity_50,tv,villa,washer,wirelessinternet',
#  'Country,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,yes,no,no,no,no,no,no,no,no,no,no,no,no,no,yes,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no',
#  'UnitedStates,no,yes,no,no,no,no,no,no,no,no,yes,no,yes,no,no,no,no,yes,no,no,yes,yes,no,no,yes,no,no,no,yes,yes,yes,no,no,no,no,yes,yes,yes,yes,no,no,no,no,no,no,no,no,yes,yes,no,no,no,no,yes,yes,yes,yes',
#  'UnitedStates,no,yes,no,no,no,no,no,no,no,no,no,no,yes,no,no,no,no,yes,no,no,yes,yes,yes,no,yes,no,no,no,yes,yes,yes,no,no,no,no,yes,yes,yes,yes,no,no,no,no,no,no,no,no,yes,yes,no,yes,no,no,yes,no,yes,yes',
#  'UnitedStates,yes,yes,no,no,no,no,no,no,no,no,yes,no,yes,no,no,no,no,yes,yes,no,yes,yes,yes,no,no,no,no,yes,yes,yes,yes,no,no,no,no,yes,yes,yes,yes,no,no,no,no,no,no,yes,no,yes,yes,yes,no,no,no,yes,no,yes,yes',
