# %%
countries = []
amens = []
with open("CountryHT_AverageAmenities.csv",newline='') as f1:
    lines = f1.readlines()
    for x in range (0,len(lines)):
        countries.append([])
        
        entries = lines[x].replace("[","").replace("]","").replace("\"","").replace(" ","").split(",")
        country = entries[0];
        countries[x].append(country + entries[1])
        for y in range(2, len(entries)):
            countries[x].append(entries[y].lower().replace("\n",""))
            if(not entries[y].lower().replace("\n","") in amens ): 
                amens.append(entries[y].lower().replace("\n",""))

amens = sorted(amens)
for am in amens:
    print(am)
countries
# Out:
# 24-hourcheck-in
# airconditioning
# breakfast
# buzzer/wirelessintercom
# cabletv
# carbonmonoxidedetector
# doorman
# dryer
# elevatorinbuilding
# essentialamenities(>40%oflistings)
# essentials
# family/kidfriendly
# fireextinguisher
# firstaidkit
# freeparkingonpremises
# gym
# hairdryer
# hangers
# heating
# indoorfireplace
# internet
# iron
# kitchen
# laptopfriendlyworkspace
# lockonbedroomdoor
# petsallowed
# petsliveonthisproperty
# pool
# safetycard
# shampoo
# smokedetector
# translationmissing:en.hosting_amenity_49
# translationmissing:en.hosting_amenity_50
# tv
# washer
# wirelessinternet
# [['CountryHousingType', 'essentialamenities(>40%oflistings)'],
#  ['UnitedStatesVilla',
#   'kitchen',
#   'laptopfriendlyworkspace',
#   'family/kidfriendly',
#   'airconditioning',
#   'iron',
#   'washer',
#   'essentials',
#   'smokedetector',
#   'shampoo',
#   'cabletv',
#   'hangers',
#   'wirelessinternet',
#   'freeparkingonpremises',
#   'tv',
#   'carbonmonoxidedetector',
# ...

# %%
results = []

header = "Country"
for am in amens:
    header += "," + am.replace("\n","")


results.append(header)
    
for country in countries:
    res = country[0]
    for am in amens:
        if am in country:
            res += ",yes"
        else: res += ",no"
    results.append(res)

# %%
results
# Out:
# ['Country,24-hourcheck-in,airconditioning,breakfast,buzzer/wirelessintercom,cabletv,carbonmonoxidedetector,doorman,dryer,elevatorinbuilding,essentialamenities(>40%oflistings),essentials,family/kidfriendly,fireextinguisher,firstaidkit,freeparkingonpremises,gym,hairdryer,hangers,heating,indoorfireplace,internet,iron,kitchen,laptopfriendlyworkspace,lockonbedroomdoor,petsallowed,petsliveonthisproperty,pool,safetycard,shampoo,smokedetector,translationmissing:en.hosting_amenity_49,translationmissing:en.hosting_amenity_50,tv,washer,wirelessinternet',
#  'CountryHousingType,no,no,no,no,no,no,no,no,no,yes,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no,no',
#  'UnitedStatesVilla,no,yes,no,no,yes,yes,no,yes,no,no,yes,yes,no,no,yes,no,yes,yes,yes,no,yes,yes,yes,yes,no,no,no,no,no,yes,yes,no,no,yes,yes,yes',
#  'UnitedStatesTownhouse,no,yes,no,no,no,yes,no,yes,no,no,yes,yes,yes,no,yes,no,yes,yes,yes,no,yes,yes,yes,yes,no,no,no,no,no,yes,yes,no,no,yes,yes,yes',
# ...

# %%
import csv
with open('CountryHt_AvAmPrettified.csv', 'w') as writer:
    for line in results:
        writer.write(line + "\n")

# %%
import csv

with open('names.csv', 'w') as csvfile:
    fieldnames = ['first_name', 'last_name']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerow({'first_name': 'Baked', 'last_name': 'Beans'})
    writer.writerow({'first_name': 'Lovely', 'last_name': 'Spam'})
    writer.writerow({'first_name': 'Wonderful', 'last_name': 'Spam'})
